# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import spline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-f5ee9b074df6> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from scipy.interpolate import spline
#
# ImportError: cannot import name 'spline' from 'scipy.interpolate' (/home/civil/mtech/cew192199/.conda/envs/myenv/lib/python3.8/site-packages/scipy/interpolate/__init__.py)

# %%
df = pd.read_csv("Indian Peninsula.csv")
df

# %%
df1 = pd.read_csv("floodlevel_IndianPeninsula.csv")
df1
# Out:
#            GaugeID           STATE                       STATION  \
# 0   IWM-gauge-0100          Kerala                    KOTTATHARA
# 1   IWM-gauge-0248      Tamil Nadu                     Odendurai
# 2   IWM-gauge-0387          Odisha                       Rajghat
# 3   IWM-gauge-0636     Maharashtra             Terwad (Seasonal)
# 4   IWM-gauge-0763       Karnataka                         Marol
# 5   IWM-gauge-0877       Karnataka                     YENNEHOLE
# 6   IWM-gauge-0880       Karnataka            Sadalga (Seasonal)
# 7   IWM-gauge-0908       Karnataka                   Gokak Falls
# 8   IWM-gauge-1061          Odisha                       Jenapur
# 9   IWM-gauge-1089     Maharashtra                     KURUNDWAD
# 10  IWM-gauge-1169     Maharashtra            Samdoli (Seasonal)
# 11  IWM-gauge-1442         Gujarat                    NANIPALSAN
# 12  IWM-gauge-1553       Karnataka                        HALADI
# ...

# %%
df3 = pd.read_csv("Gauge100Peninsula.csv")
df3
# Out:
#    Unnamed: 0         GaugeID  Start Date    End Date  Peak Flood Level (m)  \
# 0           0  IWM-gauge-0100  29-06-2017    2/7/2017                289.85
# 1           1  IWM-gauge-0100  15-09-2017  22-09-2017                289.70
# 2           2  IWM-gauge-0100  11/10/2017  18-10-2017                289.70
# 3           3  IWM-gauge-0100   8/11/2017  14-11-2017                289.67
# 4           4  IWM-gauge-0100   1/12/2017   7/12/2017                289.69
# 5           5  IWM-gauge-0100  14-12-2017  21-12-2017                289.87
#
#   Peak FL Date  Num Peak FL  Peak Discharge Q (cumec) Peak Discharge Date  \
# 0   29-06-2017            1                     11.77          29-06-2017
# 1   15-09-2017            8                      9.35          15-09-2017
# 2   11/10/2017            8                      9.52          11/10/2017
# 3    8/11/2017            7                      7.24           8/11/2017
# ...

# %%
sns.distplot(df3['Peak Flood Level (m)'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
# Out:
# /home/civil/mtech/cew192199/.conda/envs/myenv/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Peak Flood Level (m)', ylabel='Density'>

# %%
x = np.array([1, 2, 3, 4])
y = np.array([75, 0, 25, 100])

plt.plot(x, y)

# %%
x_new = np.linspace(1, 4, 300)
a_BSpline = interpolate.make_interp_spline(x, y)
y_new = a_BSpline(x_new)

plt.plot(x_new, y_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b8920699cefa> in <module>
#       1 x_new = np.linspace(1, 4, 300)
# ----> 2 a_BSpline = interpolate.make_interp_spline(x, y)
#       3 y_new = a_BSpline(x_new)
#       4
#       5 plt.plot(x_new, y_new)
#
# NameError: name 'interpolate' is not defined

# %%
x = df3["Peak Flood Level (m)"]
y = df3["Peak FL Date"]
y1 = df3["Peak Discharge Q (cumec)"]
y1
# Out:
# 0     11.77
# 1      9.35
# 2      9.52
# 3      7.24
# 4      7.01
# 5    133.27
# Name: Peak Discharge Q (cumec), dtype: float64

# %%
fig, ax = plt.subplots()
df3.plot(x="Peak FL Date", y="Peak Flood Level (m)", ax = ax)
# Out:
# <AxesSubplot:xlabel='Peak FL Date'>
